# %%
import pandas as pd

# %%
df=pd.read_table('https://github.com/sophalITC/datasci/raw/master/employee.tsv')
df
# Out:
#   gender        dob  occupation  work_exp    salary  own_house  children
# 0      M  31-Jul-89       nurse       2.2  223700.0       True         1
# 1    NaN  30-Oct-92     dentist       6.7  121100.0       True         1
# 2      F        NaN  accountant       9.0       NaN      False         2
# 3      F  17-Sep-87    engineer       1.7   79900.0      False         0
# 4      M  24-Jan-93     teacher       3.6   32800.0      False         2
# 5      F        NaN   developer       1.8       NaN       True         1
# 6      F  26-Sep-94       nurse       5.6  272500.0      False         1
# 7      M   7-May-91      lawyer       4.1   41600.0      False         0
# 8      M   4-Dec-94     teacher       3.3  141300.0       True         0
# 9      M  10-Jul-87      police       6.5   68000.0       True         1

# %%
#pandas.series (1D array)
#pandas.dataframe (2D array)
#pandas.panel (3D array)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   gender      9 non-null      object
#  1   dob         8 non-null      object
#  2   occupation  10 non-null     object
#  3   work_exp    10 non-null     float64
#  4   salary      8 non-null      float64
#  5   own_house   10 non-null     bool
#  6   children    10 non-null     int64
# dtypes: bool(1), float64(2), int64(1), object(3)
# memory usage: 618.0+ bytes

# %%
df=pd.read_table('https://github.com/sophalITC/datasci/raw/master/employee.tsv', parse_dates=['dob'])
df.tail()
# Out:
#   gender        dob occupation  work_exp    salary  own_house  children
# 5      F        NaT  developer       1.8       NaN       True         1
# 6      F 1994-09-26      nurse       5.6  272500.0      False         1
# 7      M 1991-05-07     lawyer       4.1   41600.0      False         0
# 8      M 1994-12-04    teacher       3.3  141300.0       True         0
# 9      M 1987-07-10     police       6.5   68000.0       True         1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   gender      9 non-null      object
#  1   dob         8 non-null      datetime64[ns]
#  2   occupation  10 non-null     object
#  3   work_exp    10 non-null     float64
#  4   salary      8 non-null      float64
#  5   own_house   10 non-null     bool
#  6   children    10 non-null     int64
# dtypes: bool(1), datetime64[ns](1), float64(2), int64(1), object(2)
# memory usage: 618.0+ bytes

# %%
df.salary.mean()
# Out:
# 122612.5

# %%
df.salary.sum()
# Out:
# 980900.0

# %%
df.occupation.value_counts()
# Out:
# teacher       2
# nurse         2
# developer     1
# lawyer        1
# dentist       1
# police        1
# accountant    1
# engineer      1
# Name: occupation, dtype: int64

# %%
df.occupation.str.upper()
# Out:
# 0         NURSE
# 1       DENTIST
# 2    ACCOUNTANT
# 3      ENGINEER
# 4       TEACHER
# 5     DEVELOPER
# 6         NURSE
# 7        LAWYER
# 8       TEACHER
# 9        POLICE
# Name: occupation, dtype: object

# %%
# age 
df
# Out:
#   gender        dob  occupation  work_exp    salary  own_house  children
# 0      M 1989-07-31       nurse       2.2  223700.0       True         1
# 1    NaN 1992-10-30     dentist       6.7  121100.0       True         1
# 2      F        NaT  accountant       9.0       NaN      False         2
# 3      F 1987-09-17    engineer       1.7   79900.0      False         0
# 4      M 1993-01-24     teacher       3.6   32800.0      False         2
# 5      F        NaT   developer       1.8       NaN       True         1
# 6      F 1994-09-26       nurse       5.6  272500.0      False         1
# 7      M 1991-05-07      lawyer       4.1   41600.0      False         0
# 8      M 1994-12-04     teacher       3.3  141300.0       True         0
# 9      M 1987-07-10      police       6.5   68000.0       True         1

# %%
pd.to_datetime('today').year
#pandas: 1)pandas series, 2)pandas dataframe ,3) pandas panel
# Out:
# 2022

# %%
df['age']=pd.to_datetime('today').year-df.dob.dt.year

# %%
df
# Out:
#   gender        dob  occupation  work_exp    salary  own_house  children   age
# 0      M 1989-07-31       nurse       2.2  223700.0       True         1  33.0
# 1    NaN 1992-10-30     dentist       6.7  121100.0       True         1  30.0
# 2      F        NaT  accountant       9.0       NaN      False         2   NaN
# 3      F 1987-09-17    engineer       1.7   79900.0      False         0  35.0
# 4      M 1993-01-24     teacher       3.6   32800.0      False         2  29.0
# 5      F        NaT   developer       1.8       NaN       True         1   NaN
# 6      F 1994-09-26       nurse       5.6  272500.0      False         1  28.0
# 7      M 1991-05-07      lawyer       4.1   41600.0      False         0  31.0
# 8      M 1994-12-04     teacher       3.3  141300.0       True         0  28.0
# 9      M 1987-07-10      police       6.5   68000.0       True         1  35.0

# %%
#find average age of all employee
df.age.mean()
# Out:
# 31.125

# %%
#find number of employee who has own house and does not
df.own_house.value_counts()
# Out:
# True     5
# False    5
# Name: own_house, dtype: int64

# %%
df.describe()
# Out:
#         work_exp         salary   children        age
# count  10.000000       8.000000  10.000000   8.000000
# mean    4.450000  122612.500000   0.900000  31.125000
# std     2.429106   86579.978509   0.737865   2.900123
# min     1.700000   32800.000000   0.000000  28.000000
# 25%     2.475000   61400.000000   0.250000  28.750000
# 50%     3.850000  100500.000000   1.000000  30.500000
# 75%     6.275000  161900.000000   1.000000  33.500000
# max     9.000000  272500.000000   2.000000  35.000000

# %%
df
# Out:
#   gender        dob  occupation  work_exp    salary  own_house  children   age
# 0      M 1989-07-31       nurse       2.2  223700.0       True         1  33.0
# 1    NaN 1992-10-30     dentist       6.7  121100.0       True         1  30.0
# 2      F        NaT  accountant       9.0       NaN      False         2   NaN
# 3      F 1987-09-17    engineer       1.7   79900.0      False         0  35.0
# 4      M 1993-01-24     teacher       3.6   32800.0      False         2  29.0
# 5      F        NaT   developer       1.8       NaN       True         1   NaN
# 6      F 1994-09-26       nurse       5.6  272500.0      False         1  28.0
# 7      M 1991-05-07      lawyer       4.1   41600.0      False         0  31.0
# 8      M 1994-12-04     teacher       3.3  141300.0       True         0  28.0
# 9      M 1987-07-10      police       6.5   68000.0       True         1  35.0

# %%
df.dob.dt.day_name()
# Out:
# 0      Monday
# 1      Friday
# 2         NaN
# 3    Thursday
# 4      Sunday
# 5         NaN
# 6      Monday
# 7     Tuesday
# 8      Sunday
# 9      Friday
# Name: dob, dtype: object

# %% [markdown]
# ## Pandas Series (1D array)

# %%
payment=pd.Series([100,90,110,88,124,200,58])
payment
# Out:
# 0    100
# 1     90
# 2    110
# 3     88
# 4    124
# 5    200
# 6     58
# dtype: int64

# %%
payment[1]
# Out:
# 90

# %%
payment[1:5]
# Out:
# 1     90
# 2    110
# 3     88
# 4    124
# dtype: int64

# %%
s=pd.Series([100,90,110,88,124,200,58] , index=['Jan','Feb','Mar','Apr','May','Jun','Jul'])
s
# Out:
# Jan    100
# Feb     90
# Mar    110
# Apr     88
# May    124
# Jun    200
# Jul     58
# dtype: int64

# %%
s['Jun']
# Out:
# 200

# %%
# %matplotlib inline

# %%
s.plot()
# Out:
# <AxesSubplot:>

# %%
s.plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Pandas dataframe (2D array)

# %%
df=pd.read_csv('https://github.com/sophalITC/datasci/raw/master/mpg.csv')

# %%
df.head()
# Out:
#   manufacturer model  displ  year  cyl       trans drv  cty  hwy fl    class
# 0         audi    a4    1.8  1999    4    auto(l5)   f   18   29  p  compact
# 1         audi    a4    1.8  1999    4  manual(m5)   f   21   29  p  compact
# 2         audi    a4    2.0  2008    4  manual(m6)   f   20   31  p  compact
# 3         audi    a4    2.0  2008    4    auto(av)   f   21   30  p  compact
# 4         audi    a4    2.8  1999    6    auto(l5)   f   16   26  p  compact

# %%
df.tail()
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 229   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 230   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 231   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 232   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 233   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#        class
# 229  midsize
# 230  midsize
# 231  midsize
# 232  midsize
# 233  midsize

# %%
df.sample(10)
# Out:
#     manufacturer               model  displ  year  cyl       trans drv  cty  \
# 174       toyota         4runner 4wd    2.7  1999    4    auto(l4)   4   16
# 176       toyota         4runner 4wd    3.4  1999    6  manual(m5)   4   15
# 214   volkswagen               jetta    2.0  1999    4    auto(l4)   f   19
# 200       toyota   toyota tacoma 4wd    2.7  1999    4  manual(m5)   4   15
# 228   volkswagen              passat    1.8  1999    4    auto(l5)   f   18
# 146       nissan              altima    3.5  2008    6    auto(av)   f   19
# 123         jeep  grand cherokee 4wd    3.7  2008    6    auto(l5)   4   15
# 157      pontiac          grand prix    3.8  2008    6    auto(l4)   f   18
# 148       nissan              maxima    3.0  1999    6  manual(m5)   f   19
# 84          ford     f150 pickup 4wd    4.2  1999    6  manual(m5)   4   14
#
#      hwy fl    class
# 174   20  r      suv
# 176   17  r      suv
# 214   26  r  compact
# 200   20  r   pickup
# 228   29  p  midsize
# 146   26  p  midsize
# 123   19  r      suv
# 157   28  r  midsize
# 148   25  r  midsize
# 84    17  r   pickup

# %%
df
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 0           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 1           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 2           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 3           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 4           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 229   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 230   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 231   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 232   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 233   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#        class
# 0    compact
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# ..       ...
# 229  midsize
# 230  midsize
# 231  midsize
# 232  midsize
# 233  midsize
#
# [234 rows x 11 columns]

# %%
#cty_kml
df['cty_kml']=df['cty']*0.425144
df.head()
# Out:
#   manufacturer model  displ  year  cyl       trans drv  cty  hwy fl    class  \
# 0         audi    a4    1.8  1999    4    auto(l5)   f   18   29  p  compact
# 1         audi    a4    1.8  1999    4  manual(m5)   f   21   29  p  compact
# 2         audi    a4    2.0  2008    4  manual(m6)   f   20   31  p  compact
# 3         audi    a4    2.0  2008    4    auto(av)   f   21   30  p  compact
# 4         audi    a4    2.8  1999    6    auto(l5)   f   16   26  p  compact
#
#     cty_kml
# 0  7.652592
# 1  8.928024
# 2  8.502880
# 3  8.928024
# 4  6.802304

# %%
df['hwy_kml']=df['hwy']*0.425144
df.head()
# Out:
#   manufacturer model  displ  year  cyl       trans drv  cty  hwy fl    class  \
# 0         audi    a4    1.8  1999    4    auto(l5)   f   18   29  p  compact
# 1         audi    a4    1.8  1999    4  manual(m5)   f   21   29  p  compact
# 2         audi    a4    2.0  2008    4  manual(m6)   f   20   31  p  compact
# 3         audi    a4    2.0  2008    4    auto(av)   f   21   30  p  compact
# 4         audi    a4    2.8  1999    6    auto(l5)   f   16   26  p  compact
#
#     cty_kml    hwy_kml
# 0  7.652592  12.329176
# 1  8.928024  12.329176
# 2  8.502880  13.179464
# 3  8.928024  12.754320
# 4  6.802304  11.053744

# %%
df['cty_kml']=df['cty_kml'].round(2)
df.head()
# Out:
#   manufacturer model  displ  year  cyl       trans drv  cty  hwy fl    class  \
# 0         audi    a4    1.8  1999    4    auto(l5)   f   18   29  p  compact
# 1         audi    a4    1.8  1999    4  manual(m5)   f   21   29  p  compact
# 2         audi    a4    2.0  2008    4  manual(m6)   f   20   31  p  compact
# 3         audi    a4    2.0  2008    4    auto(av)   f   21   30  p  compact
# 4         audi    a4    2.8  1999    6    auto(l5)   f   16   26  p  compact
#
#    cty_kml    hwy_kml
# 0     7.65  12.329176
# 1     8.93  12.329176
# 2     8.50  13.179464
# 3     8.93  12.754320
# 4     6.80  11.053744

# %%
df.sample(10)
# Out:
#     manufacturer                model  displ  year  cyl       trans drv  cty  \
# 165       subaru          impreza awd    2.2  1999    4    auto(l4)   4   21
# 80          ford         explorer 4wd    4.0  2008    6    auto(l5)   4   13
# 34     chevrolet               malibu    3.1  1999    6    auto(l4)   f   18
# 13          audi           a4 quattro    3.1  2008    6    auto(s6)   4   17
# 152       nissan       pathfinder 4wd    4.0  2008    6    auto(l5)   4   14
# 33     chevrolet               malibu    2.4  2008    4    auto(l4)   f   22
# 136      lincoln        navigator 2wd    5.4  2008    8    auto(l6)   r   12
# 68         dodge  ram 1500 pickup 4wd    4.7  2008    8  manual(m6)   4   12
# 208   volkswagen                  gti    2.0  1999    4    auto(l4)   f   19
# 48         dodge    dakota pickup 4wd    3.7  2008    6  manual(m6)   4   15
#
#      hwy fl       class  cty_kml    hwy_kml
# 165   26  r  subcompact     8.93  11.053744
# 80    19  r         suv     5.53   8.077736
# 34    26  r     midsize     7.65  11.053744
# 13    25  p     compact     7.23  10.628600
# 152   20  p         suv     5.95   8.502880
# 33    30  r     midsize     9.35  12.754320
# 136   18  r         suv     5.10   7.652592
# 68    16  r      pickup     5.10   6.802304
# 208   26  r     compact     8.08  11.053744
# 48    19  r      pickup     6.38   8.077736

# %%
#trans_1 
df['trans_1 ']=df['trans'].str[0]
df.sample(10)
# Out:
#     manufacturer                model  displ  year  cyl       trans drv  cty  \
# 69         dodge  ram 1500 pickup 4wd    4.7  2008    8  manual(m6)   4    9
# 22     chevrolet   c1500 suburban 2wd    6.0  2008    8    auto(l4)   r   12
# 9           audi           a4 quattro    2.0  2008    4  manual(m6)   4   20
# 107        honda                civic    2.0  2008    4  manual(m6)   f   21
# 16          audi           a6 quattro    3.1  2008    6    auto(s6)   4   17
# 63         dodge          durango 4wd    5.9  1999    8    auto(l4)   4   11
# 179       toyota                camry    2.2  1999    4  manual(m5)   f   21
# 33     chevrolet               malibu    2.4  2008    4    auto(l4)   f   22
# 145       nissan               altima    3.5  2008    6  manual(m6)   f   19
# 84          ford      f150 pickup 4wd    4.2  1999    6  manual(m5)   4   14
#
#      hwy fl       class  cty_kml    hwy_kml trans_1
# 69    12  e      pickup     3.83   5.101728        m
# 22    17  r         suv     5.10   7.227448        a
# 9     28  p     compact     8.50  11.904032        m
# 107   29  p  subcompact     8.93  12.329176        m
# 16    25  p     midsize     7.23  10.628600        a
# 63    15  r         suv     4.68   6.377160        a
# 179   29  r     midsize     8.93  12.329176        m
# 33    30  r     midsize     9.35  12.754320        a
# 145   27  p     midsize     8.08  11.478888        m
# 84    17  r      pickup     5.95   7.227448        m

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 234 entries, 0 to 233
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   manufacturer  234 non-null    object
#  1   model         234 non-null    object
#  2   displ         234 non-null    float64
#  3   year          234 non-null    int64
#  4   cyl           234 non-null    int64
#  5   trans         234 non-null    object
#  6   drv           234 non-null    object
#  7   cty           234 non-null    int64
#  8   hwy           234 non-null    int64
#  9   fl            234 non-null    object
#  10  class         234 non-null    object
#  11  cty_kml       234 non-null    float64
#  12  hwy_kml       234 non-null    float64
#  13  trans_1       234 non-null    object
# dtypes: float64(3), int64(4), object(7)
# memory usage: 25.7+ KB

# %%
df.shape
# Out:
# (234, 14)

# %%
df.mean()
# Out:
# displ         3.471795
# year       2003.500000
# cyl           5.888889
# cty          16.858974
# hwy          23.440171
# cty_kml       7.167991
# hwy_kml       9.965448
# dtype: float64

# %%
#find number of each brand 
df.manufacturer.value_counts()
# Out:
# dodge         37
# toyota        34
# volkswagen    27
# ford          25
# chevrolet     19
# audi          18
# subaru        14
# hyundai       14
# nissan        13
# honda          9
# jeep           8
# pontiac        5
# mercury        4
# land rover     4
# lincoln        3
# Name: manufacturer, dtype: int64

# %%
df.head()
# Out:
#   manufacturer model  displ  year  cyl       trans drv  cty  hwy fl    class  \
# 0         audi    a4    1.8  1999    4    auto(l5)   f   18   29  p  compact
# 1         audi    a4    1.8  1999    4  manual(m5)   f   21   29  p  compact
# 2         audi    a4    2.0  2008    4  manual(m6)   f   20   31  p  compact
# 3         audi    a4    2.0  2008    4    auto(av)   f   21   30  p  compact
# 4         audi    a4    2.8  1999    6    auto(l5)   f   16   26  p  compact
#
#    cty_kml    hwy_kml trans_1
# 0     7.65  12.329176        a
# 1     8.93  12.329176        m
# 2     8.50  13.179464        m
# 3     8.93  12.754320        a
# 4     6.80  11.053744        a

# %%
df.class.value_counts()
# Out:
#   File "<ipython-input-49-bd4b68bfb733>", line 1
#     df.class.value_counts()
#        ^
# SyntaxError: invalid syntax

# %%
df['class'].value_counts()
# Out:
# suv           62
# compact       47
# midsize       41
# subcompact    35
# pickup        33
# minivan       11
# 2seater        5
# Name: class, dtype: int64

# %%
df.describe()
# Out:
#             displ         year         cyl         cty         hwy  \
# count  234.000000   234.000000  234.000000  234.000000  234.000000
# mean     3.471795  2003.500000    5.888889   16.858974   23.440171
# std      1.291959     4.509646    1.611534    4.255946    5.954643
# min      1.600000  1999.000000    4.000000    9.000000   12.000000
# 25%      2.400000  1999.000000    4.000000   14.000000   18.000000
# 50%      3.300000  2003.500000    6.000000   17.000000   24.000000
# 75%      4.600000  2008.000000    8.000000   19.000000   27.000000
# max      7.000000  2008.000000    8.000000   35.000000   44.000000
#
#           cty_kml     hwy_kml
# count  234.000000  234.000000
# mean     7.167991    9.965448
# std      1.808473    2.531581
# min      3.830000    5.101728
# 25%      5.950000    7.652592
# 50%      7.230000   10.203456
# 75%      8.080000   11.478888
# max     14.880000   18.706336

# %%
df.describe().T
# Out:
#          count         mean       std          min          25%          50%  \
# displ    234.0     3.471795  1.291959     1.600000     2.400000     3.300000
# year     234.0  2003.500000  4.509646  1999.000000  1999.000000  2003.500000
# cyl      234.0     5.888889  1.611534     4.000000     4.000000     6.000000
# cty      234.0    16.858974  4.255946     9.000000    14.000000    17.000000
# hwy      234.0    23.440171  5.954643    12.000000    18.000000    24.000000
# cty_kml  234.0     7.167991  1.808473     3.830000     5.950000     7.230000
# hwy_kml  234.0     9.965448  2.531581     5.101728     7.652592    10.203456
#
#                  75%          max
# displ       4.600000     7.000000
# year     2008.000000  2008.000000
# cyl         8.000000     8.000000
# cty        19.000000    35.000000
# hwy        27.000000    44.000000
# cty_kml     8.080000    14.880000
# hwy_kml    11.478888    18.706336

# %%
df.corr()
# Out:
#             displ      year       cyl       cty       hwy   cty_kml   hwy_kml
# displ    1.000000  0.147843  0.930227 -0.798524 -0.766020 -0.798521 -0.766020
# year     0.147843  1.000000  0.122245 -0.037232  0.002158 -0.037298  0.002158
# cyl      0.930227  0.122245  1.000000 -0.805771 -0.761912 -0.805780 -0.761912
# cty     -0.798524 -0.037232 -0.805771  1.000000  0.955916  0.999999  0.955916
# hwy     -0.766020  0.002158 -0.761912  0.955916  1.000000  0.955891  1.000000
# cty_kml -0.798521 -0.037298 -0.805780  0.999999  0.955891  1.000000  0.955891
# hwy_kml -0.766020  0.002158 -0.761912  0.955916  1.000000  0.955891  1.000000

# %%
df
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 0           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 1           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 2           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 3           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 4           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 229   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 230   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 231   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 232   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 233   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#        class  cty_kml    hwy_kml trans_1
# 0    compact     7.65  12.329176        a
# 1    compact     8.93  12.329176        m
# 2    compact     8.50  13.179464        m
# 3    compact     8.93  12.754320        a
# 4    compact     6.80  11.053744        a
# ..       ...      ...        ...      ...
# 229  midsize     8.08  11.904032        a
# 230  midsize     8.93  12.329176        m
# 231  midsize     6.80  11.053744        a
# 232  midsize     7.65  11.053744        m
# 233  midsize     7.23  11.053744        a
#
# [234 rows x 14 columns]

# %%
df.nlargest(10,columns='cty')
# Out:
#     manufacturer       model  displ  year  cyl       trans drv  cty  hwy fl  \
# 221   volkswagen  new beetle    1.9  1999    4  manual(m5)   f   35   44  d
# 212   volkswagen       jetta    1.9  1999    4  manual(m5)   f   33   44  d
# 222   volkswagen  new beetle    1.9  1999    4    auto(l4)   f   29   41  d
# 99         honda       civic    1.6  1999    4  manual(m5)   f   28   33  r
# 196       toyota     corolla    1.8  2008    4  manual(m5)   f   28   37  r
# 104        honda       civic    1.8  2008    4  manual(m5)   f   26   34  r
# 195       toyota     corolla    1.8  1999    4  manual(m5)   f   26   35  r
# 197       toyota     corolla    1.8  2008    4    auto(l4)   f   26   35  r
# 101        honda       civic    1.6  1999    4  manual(m5)   f   25   32  r
# 105        honda       civic    1.8  2008    4    auto(l5)   f   25   36  r
#
#           class  cty_kml    hwy_kml trans_1
# 221  subcompact    14.88  18.706336        m
# 212     compact    14.03  18.706336        m
# 222  subcompact    12.33  17.430904        a
# 99   subcompact    11.90  14.029752        m
# 196     compact    11.90  15.730328        m
# 104  subcompact    11.05  14.454896        m
# 195     compact    11.05  14.880040        m
# 197     compact    11.05  14.880040        a
# 101  subcompact    10.63  13.604608        m
# 105  subcompact    10.63  15.305184        a

# %%
#find the top 10 car with highest fuel comsumption
