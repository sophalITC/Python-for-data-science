# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
from PIL import Image

# %%
# %matplotlib inline 
# %config InlineBackend.figure_format='retina'

# %%
df=pd.read_csv('https://github.com/sophalITC/datasci/raw/master/face_recog_10faces.csv')

# %%
df
# Out:
#    ImageId                                              Image
# 0        1  182 183 182 182 180 180 176 169 156 137 124 10...
# 1        2  76 87 81 72 65 59 64 76 69 42 31 38 49 58 58 4...
# 2        3  177 176 174 170 169 169 168 166 166 166 161 14...
# 3        4  176 174 174 175 174 174 176 176 175 171 165 15...
# 4        5  50 47 44 101 144 149 120 58 48 42 35 35 37 39 ...
# 5        6  177 177 177 171 142 115 97 84 89 90 88 82 63 5...
# 6        7  77 55 44 56 58 61 67 66 65 65 65 73 72 78 86 9...
# 7        8  156 160 162 166 150 114 97 105 125 127 119 121...
# 8        9  230 230 231 231 231 231 231 231 231 229 214 20...
# 9       10  132 129 126 128 146 163 170 169 143 101 71 55 ...

# %%
df.sample(5)
# Out:
#    ImageId                                              Image
# 1        2  76 87 81 72 65 59 64 76 69 42 31 38 49 58 58 4...
# 4        5  50 47 44 101 144 149 120 58 48 42 35 35 37 39 ...
# 8        9  230 230 231 231 231 231 231 231 231 229 214 20...
# 5        6  177 177 177 171 142 115 97 84 89 90 88 82 63 5...
# 9       10  132 129 126 128 146 163 170 169 143 101 71 55 ...

# %%
df.dtypes
# Out:
# ImageId     int64
# Image      object
# dtype: object

# %%
np.fromstring('1 2 3 4 5', dtype=int,sep=' ')
# Out:
# array([1, 2, 3, 4, 5])

# %%
#iloc=identity location 
df.iloc[0]['Image']
# Out:
# '182 183 182 182 180 180 176 169 156 137 124 103 79 62 54 56 58 48 49 45 39 37 42 43 52 61 78 93 104 107 114 115 117 122 120 122 118 114 115 118 117 123 122 122 112 113 118 125 124 122 109 101 96 102 108 107 100 89 76 67 58 48 44 36 32 21 12 5 15 21 24 33 32 41 52 63 71 90 106 121 152 173 180 183 182 182 183 182 182 181 182 182 183 182 182 182 182 181 181 181 182 179 177 162 136 106 84 64 49 44 40 50 50 42 36 33 32 43 51 67 77 94 106 121 124 128 127 126 128 128 129 126 126 122 128 123 128 123 129 127 133 123 128 129 135 127 122 111 115 118 120 121 118 114 107 107 99 89 74 70 59 47 29 18 16 22 25 25 34 39 45 51 52 60 84 97 124 157 175 181 183 182 183 182 184 181 183 183 183 182 182 182 182 181 180 183 182 180 176 152 111 77 59 45 36 40 51 48 37 29 29 33 45 61 81 95 107 113 120 126 129 128 132 132 130 132 132 132 131 133 130 132 129 130 133 137 136 137 135 137 137 134 129 125 126 131 131 128 128 124 124 122 121 111 105 98 86 72 62 42 27 20 19 14 15 27 40 36 27 41 56 77 107 138 163 176 
# ...

# %%
image1=np.fromstring(df.iloc[0]['Image'],dtype=int,sep=' ')
print(image1.shape)
image1
# Out:
# (9216,)
# array([182, 183, 182, ...,   8,   5,   5])

# %%
df
# Out:
#    ImageId                                              Image
# 0        1  182 183 182 182 180 180 176 169 156 137 124 10...
# 1        2  76 87 81 72 65 59 64 76 69 42 31 38 49 58 58 4...
# 2        3  177 176 174 170 169 169 168 166 166 166 161 14...
# 3        4  176 174 174 175 174 174 176 176 175 171 165 15...
# 4        5  50 47 44 101 144 149 120 58 48 42 35 35 37 39 ...
# 5        6  177 177 177 171 142 115 97 84 89 90 88 82 63 5...
# 6        7  77 55 44 56 58 61 67 66 65 65 65 73 72 78 86 9...
# 7        8  156 160 162 166 150 114 97 105 125 127 119 121...
# 8        9  230 230 231 231 231 231 231 231 231 229 214 20...
# 9       10  132 129 126 128 146 163 170 169 143 101 71 55 ...

# %%
# create numpy array from 'Image' column
df['mat']=df.apply(lambda r:np.fromstring(r['Image'],dtype=int,sep=' '),axis=1)
df
# Out:
#    ImageId                                              Image  \
# 0        1  182 183 182 182 180 180 176 169 156 137 124 10...
# 1        2  76 87 81 72 65 59 64 76 69 42 31 38 49 58 58 4...
# 2        3  177 176 174 170 169 169 168 166 166 166 161 14...
# 3        4  176 174 174 175 174 174 176 176 175 171 165 15...
# 4        5  50 47 44 101 144 149 120 58 48 42 35 35 37 39 ...
# 5        6  177 177 177 171 142 115 97 84 89 90 88 82 63 5...
# 6        7  77 55 44 56 58 61 67 66 65 65 65 73 72 78 86 9...
# 7        8  156 160 162 166 150 114 97 105 125 127 119 121...
# 8        9  230 230 231 231 231 231 231 231 231 229 214 20...
# 9       10  132 129 126 128 146 163 170 169 143 101 71 55 ...
#
#                                                  mat
# 0  [182, 183, 182, 182, 180, 180, 176, 169, 156, ...
# 1  [76, 87, 81, 72, 65, 59, 64, 76, 69, 42, 31, 3...
# 2  [177, 176, 174, 170, 169, 169, 168, 166, 166, ...
# 3  [176, 174, 174, 175, 174, 174, 176, 176, 175, ...
# ...

# %%
image4=df.iloc[3]['mat']

# %%
image4
# Out:
# array([176, 174, 174, ..., 142, 142, 140])

# %%
plt.gray()
plt.matshow(image4.reshape(96,-1))

# %%
for i in range(5):
    y=df.iloc[i]['mat']
    plt.matshow(y.reshape(96,-1), cmap='gray')

# %%
#creat z vstack df['mat'] to be 2D array
z=np.vstack(df['mat'])

# %%
print(z.shape)
# Out:
# (10, 9216)

# %%
z[9]
# Out:
# array([132, 129, 126, ...,  67,  71,  87])

# %%
plt.matshow(z[9].reshape(96,-1),cmap='gray');

# %%
def numpy_array_to_image(mat:np.array,image_name='img.png'):
    img=Image.fromarray(np.uint8(mat))
    img.save(image_name)

# %%
y=df.iloc[8]['mat']
y
# Out:
# array([230, 230, 231, ...,  35,  50,  95])

# %%
numpy_array_to_image(y.reshape(96,96),'test111.png')

# %%
Image.open('test.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=L size=96x96>
